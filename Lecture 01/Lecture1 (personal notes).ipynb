# %% [markdown]
# # <span style="color:darkblue"> Lecture 1: Introduction to Jupyter Notebooks with personal notes </span>

# %% [markdown]
# <font size="5">
#
# The basic structure for running Python
#
# <img src="figures/project_flow.png" alt="drawing" width="650"/>
#
# - Python is a general purpose language
# - Researchers and practitioners add new functionalities all the time
# - New features are included as libraries on top of the "base" installation.
#
# ***

# %% [markdown]
# <span style="color:red"> let's look at this like we're building a house... python is just the structure and we still need to add decoration and furniture and whatnot. generally outline structure before adding code </span>

# %% [markdown]
# # <span style="color:darkblue"> STEP 0: Preliminaries </span>
#
# <font size="5">
#
# We will install two libraries that are not included in "base" Python
# - "matplotlib" allows us to do nice graphs in Python
# - "pandas" allows us to work with datasets
#
#
# Open the terminal and run the commands
#
# - pip3 install matplotlib
#
# - pip3 install pandas
#
# The libraries will be added to your Python installation.
#
#
# <img src="figures/terminal-install.png" alt="drawing" width="650"/>
#
# - "pip3" is the installer command and you only need to run it once for each package.
# - Type "pip3 list" in the terminal to see currently installed packages
#
# ***

# %% [markdown]
# # <span style="color:darkblue"> STEP 1: Setup Working Environment </span>
#
# <font size="5">
#
#
# (a) Import Packages:
#
# - Jupyter notebooks will only initiate "base" Python.
# - The "import" command adds libraries to the working enviroment.
# - We can give the libraries a nickname with "as"

# %% [markdown]
# <span style="color:red"> might need to open terminal and install the packages manually </span>

# %%
# Notes about nicknames:
# - For example, "matplotlib.pyplot" is a long name. Let's call it "plt"
# - Similarly, let's call "pandas" as "pd"
# - Try adding your own nickname!
# - To avoid errors, be consistent with your nicknames

import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# <font size="5">
#
# (b) Open datasets
#
# Run the command "read_csv" from the library "pandas" (nicknamed "pd").

# %%
# You can use "." to run subcommands contained in a library.
# The subcommand "read_csv()" opens the file in parenthesis.
# We use the "=" symbol to store the dataset in the working environment under the name "carfeatures"

carfeatures = pd.read_csv('data/features.csv')
life = pd.read_csv('/Users/isaacgazmararian/Documents/qtm151spring2023/Personal Data/Journal_Data_230118.csv')

# %% [markdown]
# <font size="5">
#
# You can open the datasets in the current environment
# - Click on the "Variables" button in the top bar to open a panel
#
# <img src="figures/topbar.png" alt="drawing" width="650"/>
#
# - Double click on "carfeatures" in the "Jupyter: Variables" tab
#
# <img src="figures/sampledata.png" alt="drawing" width="650"/>
#
# - Each row is an observation (a car)
# - Each column is the value of a variable (a feature of that car)

# %% [markdown]
# ***

# %% [markdown]
# # <span style="color:darkblue"> STEP 2: Run Analyses </span>
#
# <font size="5">
#
# Output data for all the columns

# %%
# Entering the name of a dataframe produces an output with some rows

carfeatures
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration vehicle id
# 0    18.0          8           307        130    3504          12.0  C-1689780
# 1    15.0          8           350        165    3693          11.5  B-1689791
# 2    18.0          8           318        150    3436          11.0  P-1689802
# 3    16.0          8           304        150    3433          12.0  A-1689813
# 4    17.0          8           302        140    3449          10.5  F-1689824
# ..    ...        ...           ...        ...     ...           ...        ...
# 393  27.0          4           140         86    2790          15.6  F-1694103
# 394  44.0          4            97         52    2130          24.6  V-1694114
# 395  32.0          4           135         84    2295          11.6  D-1694125
# 396  28.0          4           120         79    2625          18.6  F-1694136
# 397  31.0          4           119         82    2720          19.4  C-1694147
#
# [398 rows x 7 columns]

# %%
life
# Out:
#               Timestamp What positive things have happened today (if any)?  \
# 0     8/19/2022 3:52:47  Spending time with Karina, going for run and h...
# 1     8/20/2022 0:43:11  Meeting David Kennerly video call, watching Lo...
# 2     8/21/2022 2:41:26  Calling Alyssa, Catching up with Samir, Nandis...
# 3     8/22/2022 1:57:35  Antico’s pizza with trev, Charlie, and kheyal,...
# 4     8/23/2022 2:08:53  Ran into Simon Cho, Karina conversation about ...
# ..                  ...                                                ...
# 145  1/13/2023 23:23:09  Ran into mom and chatted for a bit on boardwal...
# 146  1/14/2023 23:26:13  Playing battleship with Karina at dinner, Mia ...
# 147  1/15/2023 23:27:34  Hot tub convos about morality and taking a sho...
# 148  1/16/2023 23:29:20  Going on hike and discovering fallen tree and ...
# 149  1/17/2023 23:17:44            Meeting with Molly, evening with Karina
#
#     What negative things have happened today (if any)?  \
# ...

# %% [markdown]
# <font size="5">
#
# Output data for a single column 'cylinders'

# %%
# We use square brackets [...] to subset information from data 
# Text/strings have to be written in quotation marks
# This command extracts the column 'cylinders'

carfeatures['weight']
# Out:
# 0      3504
# 1      3693
# 2      3436
# 3      3433
# 4      3449
#        ...
# 393    2790
# 394    2130
# 395    2295
# 396    2625
# 397    2720
# Name: weight, Length: 398, dtype: int64

# %%
life['Did you make the most of today?']
# Out:
# 0      5
# 1      4
# 2      3
# 3      4
# 4      5
#       ..
# 145    5
# 146    5
# 147    4
# 148    5
# 149    5
# Name: Did you make the most of today?, Length: 150, dtype: int64

# %% [markdown]
# <font size="5">
#
# Example: Compute a frequency table

# %%
# crosstab counts how many rows fall into categories
# "index" is the category
# "columns" is a custom title

pd.crosstab(index = carfeatures['acceleration'],columns = "How many cars have (x) acceleration?")
# Out:
# col_0         How many cars have (x) acceleration?
# acceleration
# 8.0                                              1
# 8.5                                              2
# 9.0                                              1
# 9.5                                              2
# 10.0                                             4
# ...                                            ...
# 22.2                                             2
# 23.5                                             1
# 23.7                                             1
# 24.6                                             1
# 24.8                                             1
#
# [95 rows x 1 columns]

# %%
#-- Try the command again but this time change the title

# %% [markdown]
# <font size="5">
#
# Example: Compute basic summary statistics for all variables

# %%
# "describe" computes the count, mean, std, min, 25% quantile, 50%, 75%, max
# automatically excludes variables with text values
# otherwise includes all numeric variables

carfeatures.describe()
# Out:
#               mpg   cylinders  displacement       weight  acceleration
# count  398.000000  398.000000    398.000000   398.000000    398.000000
# mean    23.514573    5.454774    193.427136  2970.424623     15.568090
# std      7.815984    1.701004    104.268683   846.841774      2.757689
# min      9.000000    3.000000     68.000000  1613.000000      8.000000
# 25%     17.500000    4.000000    104.250000  2223.750000     13.825000
# 50%     23.000000    4.000000    148.500000  2803.500000     15.500000
# 75%     29.000000    8.000000    262.000000  3608.000000     17.175000
# max     46.600000    8.000000    455.000000  5140.000000     24.800000

# %%
life.describe()
# Out:
#        Did you make the most of today?  How much fun did you have?  \
# count                       150.000000                  150.000000
# mean                          4.380000                    3.580000
# std                           0.931694                    1.069843
# min                           1.000000                    1.000000
# 25%                           4.000000                    3.000000
# 50%                           5.000000                    4.000000
# 75%                           5.000000                    4.000000
# max                           5.000000                    5.000000
#
#        How productive have you felt outside of yourself?  \
# count                                         150.000000
# mean                                            3.593333
# std                                             1.147490
# min                                             1.000000
# 25%                                             3.000000
# ...

# %% [markdown]
# <font size="5">
#
# Example: Display a scatter plot

# %%
plt.scatter(x = carfeatures['displacement'], y = carfeatures['mpg'])
plt.show()

# %%
import seaborn as sb

plt.scatter(x = life["How much social cohesion did you feel?"].astype(int), y = life["Did you make the most of today?"].astype(int))
plt.show()

sb.swarmplot(x = life["How much social cohesion did you feel?"].astype(int), y = life["Did you make the most of today?"].astype(int))
sb.despine()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 7.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 38.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/seaborn/categorical.py:3544: UserWarning: 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
life["How much social cohesion did you feel?"].astype(int).describe()

life["How much social cohesion did you feel?"].isna().sum()
# Out:
# 0

# %%
life["Did you make the most of today?"].astype(int).describe()

life["Did you make the most of today?"].astype(int).isna().sum()
# Out:
# 0

# %%
# Try another scatter plot with x = "acceleration"

# %% [markdown]
# # <span style="color:darkblue"> Pro Tips: How to be a great student for QTM 151?
#  </span>
#
# <font size="5">
#
# - Ask clarifying questions (I love questions!), e.g.
#
#     -  Can you explain what this command is doing?
#     -  What are the arguments of this function?
#     -  What is the output?
#     -  I get an error saying .... (be explicit), what could be the issue?
#     -  Ask about deadlines, expectations, etc.

# %% [markdown]
# <font size="5">
#
# - Remember that good coders ...
#
#     -  build up their toolkit of commands over time
#     -  understand that errors are normal the first time you run a command
#     -  learn to use online websites to interpret errors, https://stackoverflow.com/questions/tagged/python
#     -  search help pages to find proper syntax, e.g. https://www.w3schools.com/python/

# %% [markdown]
# <font size="5">
#
# - Experiment
#
#     -  If we do analyses for variable "A", try it for "B"
#     -  Search online how to do something extra, e.g. change the color of a scatter plot
#     -  Try running the syntax deliberately wrong: helps you figure out the right logic
#     -  Think long term: Figuring out a puzzle today, means that you can use the code for the next time!

# %% [markdown]
# <font size="5">
#
# - Come to office hours
#
#     -  Best time for a one-on-one!
#     -  Good place to ask about topics not covered in the lecture
