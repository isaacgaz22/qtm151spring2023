# %% [markdown]
# # <span style="color:darkblue"> Lecture 23 - Practicing Time and Plots  </span>
#
# <font size = "5">
#
# In  this lecture we will practice working with time in Python
#
# - There will be a quiz on this lecture

# %% [markdown]
# # <span style="color:darkblue"> I. Review of time commands </span>
#
# <font size = "5">
#
# Line plot: $\qquad \qquad \qquad \quad \ $ ``` plt.plot() ```
#
# Parse string column to date: $\ $``` pd.to_datetime(data_column,format)```
#
# Date to string:  $\qquad \qquad \quad \ $ ```.dt.strftime(format)```
#
# Group by time period:
# $\qquad \ \ $ ``` pd.Grouper(key='date', freq='m')```
#
# Include group as column: $\quad$ ```.reset_index()```
#
# Difference between periods: $\ $``` .diff() ```
#
# Lag a periods: $\qquad \qquad \quad \ $ ``` .shift(1) ```
#
# Between two periods (bool): $\ $ ```.between("date1","date2")```
#
# Convert wide to long: $\qquad \quad $ ``` pd.melt(...) ```
#
# Convert long to wide: $\qquad \quad $ ``` pd.pivot(...) ```

# %% [markdown]
# ## <span style="color:darkblue"> II. Quiz Structure </span>
#
# <font size = "5">
#
# The day of the quiz I will ...
# - Provide a dataset with information
# - Give more specific instructions.
# - Below, you will see the type of questions that will be asked.
# - The idea is for you to apply known concepts to new data
# - You have 50 minutes to complete the assignment
#
# Questions
#
# (exact wording may change in quiz, but exercise will be very similar)
#
# The quiz will use a time series dataset

# %% [markdown]
# <font size = "5">
#
# (a) Import a dataset, parse date column using wildcards <br>
# $\quad$ (see Lecture 21), and sort dataset
#
# (b) Line plots from multiple columns with a legend
#
# (c) Compute growth rates for a time series
#
# (d) Flag a subset of the data and produce a shaded plot <br>
# $\quad$ as in Lecture 22
#
# (e) Compute aggregate dataset by time period
#
# (f) Convert a dataset to long format

# %%
#a)

import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
from datetime import date, time, datetime

# %%
journal = pd.read_csv("/Users/isaacgazmararian/Documents/qtm151spring2023/Personal Data/Journal_Data_230201.csv")

# %%
journal["date"] = pd.to_datetime(journal["Timestamp"])

cols_to_drop = journal.filter(like='Unnamed: ', axis=1).columns

additional_cols = ['Are you happy with the quality of your work?','Which of these values do you felt you actively lived today?', 'Any reflection about your mission statement?', 'Did you struggle with any of these values today?','Brand',]

cols_to_drop = cols_to_drop.union(additional_cols)

journal_clean = journal.drop(columns=cols_to_drop)

# %%
display(journal_clean)
# Out:
#              Timestamp What positive things have happened today (if any)?  \
# 0    1/29/2023 0:22:07  Dancing and playing with Karina while my AI re...
# 1    1/28/2023 0:26:41  Finishing up thesis animation notes and gettin...
# 2    1/27/2023 1:08:26  Lunch with Alex chatting about CMF, rushing to...
# 3    1/26/2023 0:06:29  Went for run and thought of new CMF idea which...
# 4    1/25/2023 0:12:31  Deep lunch convo with Jaeden about soulmates, ...
# ..                 ...                                                ...
# 159  8/20/2022 0:43:11  Meeting David Kennerly video call, watching Lo...
# 160  8/19/2022 3:52:47  Spending time with Karina, going for run and h...
# 161  1/30/2023 1:25:56  Playing smash bros with Diego and demetrios, w...
# 162  1/31/2023 1:03:42             Recording podcast episode of inception
# 163   2/1/2023 1:27:27  Meeting and catching up with Matt Lincoln, din...
#
#     What negative things have happened today (if any)?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
# 162                                                NaN
# 163  Absolutely overwhelmed, meetings back to back,...
#
#      Did you make the most of today?  How much fun did you have?  \
# 0                                  5                           4
# 1                                  5                           5
# 2                                  5                           5
# 3                                  5                           5
# 4                                  5                           4
# ..                               ...                         ...
# 159                                4                           3
# 160                                5                           4
# 161                                5                           5
# 162                                4                           3
# 163                                3                           2
#
#      How productive have you felt outside of yourself?  \
# 0                                                    5
# 1                                                    5
# 2                                                    5
# 3                                                    5
# 4                                                    4
# ..                                                 ...
# 159                                                  2
# 160                                                  4
# 161                                                  5
# 162                                                  4
# 163                                                  4
#
#      Would you have preferred more or less social interaction?  \
# 0                                                    3
# 1                                                    3
# 2                                                    3
# 3                                                    3
# 4                                                    3
# ..                                                 ...
# 159                                                  3
# 160                                                  3
# 161                                                  3
# 162                                                  3
# 163                                                  3
#
#      How emotionally healthy did you feel throughout the day?  \
# 0                                                    5
# 1                                                    5
# 2                                                    5
# 3                                                    5
# 4                                                    3
# ..                                                 ...
# 159                                                  4
# 160                                                  4
# 161                                                  5
# 162                                                  5
# 163                                                  2
#
#      How close do you feel to being burned out?  \
# 0                                             3
# 1                                             1
# 2                                             2
# 3                                             3
# 4                                             4
# ..                                          ...
# 159                                           3
# 160                                           1
# 161                                           3
# 162                                           4
# 163                                           5
#
#      How much personal time did you have?  ...  \
# 0                                       3  ...
# 1                                       5  ...
# 2                                       5  ...
# 3                                       2  ...
# 4                                       2  ...
# ..                                    ...  ...
# 159                                     2  ...
# 160                                     4  ...
# 161                                     5  ...
# 162                                     2  ...
# 163                                     2  ...
#
#      Are there any emotions you're processing right now you'd like to keep track of?  \
# 0                              Feeling love for karina
# 1                                                  NaN
# 2                                                  NaN
# 3    Feeling strongly about doing spring break with...
# 4               Feeling a bit sad with how much I work
# ..                                                 ...
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
# 162                                                NaN
# 163  Should follow up with Isabel and frame it as ‘...
#
#     Are there any friend life events mentioned today you want to keep in mind for the future?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                              Ben got into Princeton!
# 3                                                  NaN
# 4                            Ben has job interview tmr
# ..                                                 ...
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
# 162                                                NaN
# 163                                                NaN
#
#                Any Karina things you want to remember?  \
# 0    Fun time taking photos on her phone, we danced...
# 1                                                  NaN
# 2    Really fun going to do errands with her and ru...
# 3                                                  NaN
# 4    Bumped into her in DCT with Audra. At bell pepper
# ..                                                 ...
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
# 162                                                NaN
# 163                                                NaN
#
#     Has there been any small thing you’ve done/thought about today that you’re proud of yourself for?  \
# 0    Realizing importance of having dinner with par...
# 1                                                  NaN
# 2                                                  NaN
# 3            Taken night off to do person project work
# 4                                                  NaN
# ..                                                 ...
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
# 162          Going for run in morn despite being tired
# 163                                                NaN
#
#     How well did you feel you had the time to do everything you wanted?  \
# 0                                                  3.0
# 1                                                  4.0
# 2                                                  4.0
# 3                                                  4.0
# 4                                                  2.0
# ..                                                 ...
# 159                                                NaN
# 160                                                NaN
# 161                                                4.0
# 162                                                2.0
# 163                                                1.0
#
#      What do you want to do in order tomorrow morning?  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                            Run, professional, thesis
# 4    Run and CMF brainstorm, doodle edit, linkedin,...
# ..                                                 ...
# 159                                                NaN
# 160                                                NaN
# 161                                                NaN
# 162                                                NaN
# 163                                                NaN
#
#      What are your overall priorities tomorrow?  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ..                                          ...
# 159                                         NaN
# 160                                         NaN
# 161                                         NaN
# 162                                         NaN
# 163                                         NaN
#
#                                        Thesis updates?  \
# 0    AU work, reached out to actors, finally figure...
# 1    Got through all animation notes!! Issue with c...
# 2    Stumped with NLA editor but draise helped me f...
# 3    Kazama gave great notes. Lot of good planning ...
# 4    Showed to Joel who loved it. Good critiques bu...
# ..                                                 ...
# 159                                                NaN
# 160                                                NaN
# 161          Lot of AI work done, showing to Barba tmr
# 162                                                NaN
# 163                                                NaN
#
#     What's one thing you want to remember for tomorrow?                date
# 0                                                  NaN  2023-01-29 00:22:07
# 1                                                  NaN  2023-01-28 00:26:41
# 2                                                  NaN  2023-01-27 01:08:26
# 3                                                  NaN  2023-01-26 00:06:29
# 4                                                  NaN  2023-01-25 00:12:31
# ..                                                 ...                  ...
# 159                                                NaN  2022-08-20 00:43:11
# 160                                                NaN  2022-08-19 03:52:47
# 161                                                NaN  2023-01-30 01:25:56
# 162                                                NaN  2023-01-31 01:03:42
# 163                                                NaN  2023-02-01 01:27:27
#
# [164 rows x 31 columns]
